# %% [markdown]
# # TED – Topic Modeling

# %%
# standard libraries
from collections import Counter
from collections import OrderedDict
import pickle
import random
import re
import string
import time

# web scraping
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import requests

# data manipulation & storage
import pandas as pd

# Sklearn
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics.pairwise import cosine_similarity

# NLP
from gensim import matutils, models
import spacy
import scipy.sparse
# import stanfordnlp
# from spacy_stanfordnlp import StanfordNLPLanguage


# visualization
from spacy import displacy
from tabulate import tabulate
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel
from gensim.utils import simple_preprocess

# %% [markdown]
# ## Options

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.width', 10)
# pd.options.display.max_columns = None

# %% [markdown]
# # Web Scraping
# ##### Features to be scraped
# * Speaker (author)
# * Title
# * Transcript
# * Related tags
# * About the talk
#
# ##### Nice to have for future work
# * Date
# * About the speaker
# * Views
# * Talk length

# %%
def make_soup(url):
    """
    Make soup for each Ted Talk transcript url.
    """
    # Generate random user-agent
    user_agent = {'User-agent': UserAgent().random}
    
    # Request page and make soup
    page = requests.get(url, headers=user_agent)
    soup = BeautifulSoup(page.content, 'lxml')
    return soup

# %%
def get_max_page():
    """
    Get's the max pagination number from Ted's home page.
    """
    page_num = []
    
    # Set language to English and sort by newest talks
    soup = make_soup('https://www.ted.com/talks?language=en&page=1&sort=newest')
    
    # Iterate through each pagination element and get the max
    for element in soup.find_all('a', class_='pagination__item pagination__link'):
        page_num.append(int(element.text))
    return max(page_num)

# %%
def get_talk_urls():
    """
    Get's all the talk urls in each talks page.
    Filters for talks in English.
    """
    talk_url_list = []
    
    # Set language to English
    talks_url = 'https://www.ted.com/talks?language=en&page='
    
    # Set range from 1 to the max page in the pagination element
    page_range = range(1, get_max_page()+1)
    
    # Iterate through each page and get the url for each talk
    for i in page_range:
        
        # Try a second attempt if first attempt fails
        for attempt in range(2):
            try:
                talks_page_url = talks_url + str(i) + '&sort=newest'
                soup = make_soup(talks_page_url)

                # Delay between searches
                time.sleep(random.uniform(1, 2))

                for div in soup.find_all('div', attrs={'class': 'media__image'}):
                    for a in div.find_all('a'):
                        talk_url_list.append(a.get('href'))
            except:
                # Delay before continuing to second attempt
                time.sleep(random.uniform(2, 3))
            
            # Break if no exceptions are raised
            else:
                break
            
    return talk_url_list

# %%
def construct_url():
    """
    Construct complete url for each talk's transcript page.
    Removes '?language=en' from the end of the url.
    """
    return ['https://www.ted.com' + url.replace('?language=en', '') + '/transcript' for url in get_talk_urls()]

# %%
def get_data():
    """
    Get title, speaker, related tags, and transcript from each talk's transcript page.
    Returns data in a nested dictionary.
    """
    # Create empty dict to nest dicts (1 nested dict per talk)
    ted_dict = {}
    
    # 1. Used to create nested dicts in 'ted_dict'
    # 2. Used as count for successfully scraped pages
    dict_id = 0
    
    # Counter for failed scraped pages
    failed_counter = 0
    
    # Iterate through each ted talk transcript url
    for url in construct_url():
        # Make soup
        soup = make_soup(url)

        # Delay between searches
        time.sleep(random.uniform(.5, 2))
        
        # Try up to three attempts to scrape data
        for attempt in range(1, 3+1):
            try:    
                # Get title
                title_tag = soup.find(attrs={'name': 'title'})

                # Get speaker
                speaker_tag = soup.find(attrs={'name': 'author'})

                # Get related tags
                match_obj = re.search(r"\"tag\":\"(.*?)\"", soup.text)
                match_obj.group(1)
                ted_tags = match_obj.group(1).split(',')

                # Get talk description
                desc_tag = soup.find(attrs={'property': 'og:description'})
                desc_str = desc_tag.attrs['content'].split(': ', 1)[1] # Split description at "TED Talk Subtitles and Transcript:"

                # Get transcript
                transcript = ''
                transcript_strings = []
                for div in soup.find_all('div', class_="Grid__cell flx-s:1 p-r:4"):
                    for p in div.find_all('p'):
                        # Add every string in the transcript to a list
                        transcript_strings.append(" ".join(p.text.split()))
                    else:
                        # After all strings have been added, create a single transcript string
                        transcript = " ".join(transcript_strings)

                # Add 1 to create a new dict_id and use it to create a nested dict
                dict_id += 1
                ted_dict[dict_id] = {}

                # Add the features above to the nested dict
                ted_dict[dict_id]['title'] = title_tag.attrs['content'].split(':')[1].strip()
                ted_dict[dict_id]['speaker'] = speaker_tag.attrs['content']
                ted_dict[dict_id]['tags'] = ted_tags
                ted_dict[dict_id]['description'] = desc_str
                ted_dict[dict_id]['transcript'] = transcript
                
                # Indicate successfull scrape
                print(dict_id, url)

            except Exception as e:
                # If the last attempt fails, update the failed counter and print the exception & talk url for debugging
                if attempt == 3:
                    failed_counter += 1
                    print(f'position: {dict_id}, exception: {e}, url: {url}\n')
                    continue
                
                # Delay before another attempt
                time.sleep(random.uniform(4, 6))
            
            # Break if no exceptions are raised
            else:
                break

    print(f"""Ted.com scraping results:
        \n\t• Success: {dict_id}
        \n\t• Failed: {failed_counter}\n""")
    
    return ted_dict

# %%
# ted_dict = get_data()
# print(ted_dict)

# %% [markdown]
# ## Create dataframe

# %%
# Save pickle
# with open('data/ted_dict_complete.pkl', 'wb') as f:
#     pickle.dump(ted_dict, f)

# Load pickle
with open('data/ted_dict_complete.pkl', 'rb') as f:
    ted_dict = pickle.load(f)
    print(f"# of dictionaries in:\n •'ted_dict': {len(ted_dict)}")

# %%
# Load all data scraped from TED

# Create dataframe
# df = pd.DataFrame.from_dict(ted_dict, orient='index')

# Pickle dataframe
# df.to_pickle('data/first_df.pkl')

# Load dataframe from pickle
df = pd.read_pickle('data/first_df.pkl')
print(df.shape)

# %% [markdown]
# We were able to successfully scrape 3904 talks (as of February 21, 2020)!
#
# Only one talk failed as the transcript doesn't load, maybe we should notify TED about this bug...
# https://www.ted.com/talks/marcus_bullock_an_app_that_helps_incarcerated_people_stay_connected_to_their_families/transcript

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# * Load data and create a dataframe
# * Reduce scope
# * Clean data, remove:
#     * text in square brackets & parenthesis
#     * punctuation
#     * words containing numbers
#     * double-quotes, dashes
# * Lemmatization (spaCy)
# * Save stop words (spaCy)
# * Create corpus from nouns & adjectives (spaCy)
#     * One for each tag: sex, religion, politics
# * Create document-term matrix

# %% [markdown]
# ## Load data and create a dataframe

# %%
# Load pickled dictionary of scraped data
with open('data/ted_dict_complete.pkl', 'rb') as f:
    ted_dict = pickle.load(f)
    print(f"# of dictionaries in:\n •'ted_dict': {len(ted_dict)}\n")

    # Create a dataframe
    df = pd.DataFrame.from_dict(ted_dict, orient='index')
    f.close()

# Pickle dataframe
df.to_pickle('data/first_df.pkl')

# Load dataframe from pickle
df = pd.read_pickle('data/first_df.pkl')
print(f'Shape: {df.shape}')
# Out:
# # of dictionaries in:
#  •'ted_dict': 3904
#
# Shape: (3904, 5)

# %% [markdown]
# ## Reduce Scope
# Filter for talks about `sex`, `religion`, and `politics`

# %% [markdown]
# https://stackoverflow.com/questions/16575868/efficiently-creating-additional-columns-in-a-pandas-dataframe-using-map

# %%
def check_tag(tag):
    """Input tag and return a list of booleans for talks that contain 'tag' by index"""
    contains_tag = []
    for ix, tag_list in enumerate(df['tags']):
        if any(tag in t for t in tag_list):
            contains_tag.append(1)
        else:
            contains_tag.append(0)
    return contains_tag

# %%
# Add series for selected tags
df['is_sex'] = check_tag('sex')
df['is_religion'] = check_tag('religion')
df['is_politics'] = check_tag('politics')

# %%
# Filter dataframe to only include talks for the selected tags
df = df.loc[(df['is_sex']==1) | (df['is_religion']==1) | (df['is_politics']==1), : ].reset_index()

# %% [markdown]
# ### Create new dataframe with reduced scope

# %%
def combine_transcripts(list_of_text):
    """Input a list of text and return them into one large chunk of text."""
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
def transcripts_to_dict(dataframe, tag_list):
    """Creates a dictionary of transcripts for each tag.
    Input a dataframe and tag list.
    Return a nested dictionary.
    """
    ted_dict = {}
        
    # Assign parameter to tags
    tags = tag_list
    for tag in tag_list:
        # Filter dataframe to specific series and convert it to a list
        filter_string = 'is_' + str(tag)
        text_list = dataframe.loc[(df[filter_string]==1), 'transcript'].to_list()

        # Call combine_transcripts function to return combined text
        combined_text = combine_transcripts(text_list)

        # Add combined text to dict
        ted_dict[tag] = combined_text
    return ted_dict

# %%
# Create dictionary from the dataframe
transcript_dict = transcripts_to_dict(df, ['sex', 'religion', 'politics'])

# Construct dataframe from dictionary 
df = pd.DataFrame.from_dict(transcript_dict, orient='index')
df.rename({0: 'transcript'}, axis=1, inplace=True)

# %% [markdown]
# ## Clean text

# %%
def clean_text(text):
    '''
    Remove:
        *text in square brackets & parenthesis
        *punctuation
        *words containing numbers
        *double-quotes, dashes
    '''
#     text = text.lower()
    text = re.sub('[\[\(].*?[\)\]]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[\“\–]', '', text)
    return text

# %%
# Clean text
df['transcript'] = pd.DataFrame(df['transcript'].apply(lambda x: clean_text(x)))
# df['description'] = pd.DataFrame(df['description'].apply(lambda x: clean_text(x)))
# df['title'] = pd.DataFrame(df['title'].apply(lambda x: clean_text(x)))

# %%
# # Pickle dataframe
# df.to_pickle('data/sex_religion_politics_corpus.pkl')

# Load dataframe
df = pd.read_pickle('data/sex_religion_politics_corpus.pkl')
print(f'Shape: {df.shape}')
# Out:
# Shape: (3, 1)

# %% [markdown]
# ## Corpus

# %% [markdown]
# ### Process the corpus with spaCy

# %%
# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Transform dataframe to list of docs (corpus)
texts = df.loc[:, 'transcript'].to_list()

# Process the corpus
docs = list(nlp.pipe(texts)) # disable=['tagger', 'parser', 'textcat']

# %%
# # Pickle docs
# with open('data/docs_transcript.pkl', 'wb') as f:
#     pickle.dump(docs, f)
#     f.close()

# Load pickled spaCy 'docs' object
with open('data/docs_transcript.pkl', 'rb') as f:
    docs = pickle.load(f)
    f.close()

# %%
def get_stop_words(spaCy_doc_obj):
    """Input a Doc and return a list of spaCy stop words"""
    stop_words = []
    for doc in spaCy_doc_obj:
        for token in doc:
            if token.is_stop:
                stop_words.append(token.text.lower())
    return set(stop_words)

# %%
# spaCy stop words from transcripts
spacy_stop_words = get_stop_words(docs)

# # Pickle spacy_stop_words for later use
# with open('data/spacy_stop_words.pkl', 'wb') as f:
#     pickle.dump(spacy_stop_words, f)
#     f.close()

# %% [markdown]
# ### Corpus: Nouns & adjectives
# Only includes nouns & adjectives

# %%
def get_nouns_adj(spaCy_doc, tag_list):
    """
    Input a spaCy Doc object (corpus) and tag list.
    Return a dictionary of lemmatized nouns and adjectives per doc.
    """
    tags = tag_list
    my_dict = {}
    for ix, doc in enumerate(spaCy_doc):
        tag = tags[ix]
        token_list = []
        for token in doc:
            if token.pos_ in ['NOUN', 'ADJ']:
                token_list.append((token.lemma_).lower())
        my_dict[tag] = ' '.join(token_list)
    return my_dict

# %%
# Create nouns and adjective dictionary
nouns_adj_dict = get_nouns_adj(docs, ['sex', 'religion', 'politics'])

# %%
# Construct dataframe
nouns_adj_df = pd.DataFrame.from_dict(nouns_adj_dict, orient='index')
nouns_adj_df.rename({0: 'transcript'}, axis=1, inplace=True)
nouns_adj_df.head()
# Out:
#                                                  transcript
# sex       teen terrible period crippling cramp blood clo...
# religion  primordial destroyer evil slayer demon protect...
# politics  team researcher math test exam american adult ...

# %%
# # Pickle dataframe
# nouns_adj_df.to_pickle('data/processed_transcript_df.pkl')

# # Load dataframe
# nouns_adj_df = pd.read_pickle('data/processed_transcript_df.pkl')
# print(f'Shape: {df.shape}')

# %% [markdown]
# ## Document-Term Matrix

# %%
# Use spaCy stop words
cv = CountVectorizer(stop_words=spacy_stop_words)
data_cv = cv.fit_transform(nouns_adj_df['transcript'])
dtm_df = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
dtm_df.index = df.index
dtm_df
# Out:
# /Users/miguel/anaconda3/envs/metis/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
#           abathembu  abaya  abbreviation  abduction  aberration  abhorrent  \
# sex               0      0             1          1           0          1
# religion          0      1             0          0           0          1
# politics          1      0             0          0           1          1
#
#           ability  able  ablebodied  ableism  ...  zipper  zombie  zone  \
# sex            20    62           0        0  ...       0       0     2
# religion       16    54           1        0  ...       0       1     1
# politics       80   203           0        1  ...       3       5    34
#
#           zoning  zoo  zucchini  zygote  élan  état  送你葱
# sex            1    0         1       1     1     0    0
# religion       1    0         0       0     0     0    0
# politics       2    5         0       0     0     2    1
#
# [3 rows x 12385 columns]

# %%
# # Pickle document-term matrix
# dtm_df.to_pickle('data/dtm_nouns_adj.pkl')

# Load document-term matrix
dtm_df = pd.read_pickle('data/dtm_nouns_adj.pkl')
print(f'Shape: {dtm_df.shape}')
# Out:
# Shape: (3, 12385)

# %% [markdown]
# # Exploratory Data Analysis
#
# * Word Clouds

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
# Read in the document-term matrix
data = pd.read_pickle('data/dtm_nouns_adj.pkl')
data = dtm_df.transpose()
data.head()
# Out:
#           abathembu  abaya  abbreviation  abduction  aberration  abhorrent  \
# sex               0      0             1          1           0          1
# religion          0      1             0          0           0          1
# politics          1      0             0          0           1          1
#
#           ability  able  ablebodied  ableism  ...  zipper  zombie  zone  \
# sex            20    62           0        0  ...       0       0     2
# religion       16    54           1        0  ...       0       1     1
# politics       80   203           0        1  ...       3       5    34
#
#           zoning  zoo  zucchini  zygote  élan  état  送你葱
# sex            1    0         1       1     1     0    0
# religion       1    0         0       0     0     0    0
# politics       2    5         0       0     0     2    1
#
# [3 rows x 12385 columns]

# %%
# Find the top words said by each tag
n_words = 15
top_dict = {}
for tag in data.columns:
    top = data[tag].sort_values(ascending=False).head(n_words)
    top_dict[tag]= list(zip(top.index, top.values))
    
# Print the top words said by each tag
for tag, top_words in top_dict.items():
    print(tag)
    print(', '.join([word for word, count in top_words[0:n_words]]))
    print('---')
# Out:
# sex
# woman, sex, people, man, thing, time, sexual, way, year, girl, lot, child, male, good, life
# ---
# religion
# people, world, thing, way, time, life, religion, year, good, human, man, religious, idea, compassion, day
# ---
# politics
# people, world, year, thing, country, way, time, power, good, political, government, new, idea, problem, woman
# ---

# %% [markdown]
# ## Update stop words

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top words for each tag
words = []
for tag in data.columns:
    top = [word for (word, count) in top_dict[tag]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['woman',
#  'sex',
#  'people',
#  'man',
#  'thing',
#  'time',
#  'sexual',
#  'way',
#  'year',
#  'girl',
#  'lot',
#  'child',
#  'male',
#  'good',
#  'life',
#  'people',
#  'world',
#  'thing',
#  'way',
#  'time',
#  'life',
#  'religion',
#  'year',
#  'good',
#  'human',
#  'man',
#  'religious',
#  'idea',
#  'compassion',
#  'day',
#  'people',
#  'world',
#  'year',
#  'thing',
#  'country',
#  'way',
#  'time',
#  'power',
#  'good',
#  'political',
#  'government',
#  'new',
#  'idea',
#  'problem',
#  'woman']

# %%
# Let's aggregate this list and identify the most common words
Counter(words).most_common()
# Out:
# [('people', 3),
#  ('thing', 3),
#  ('time', 3),
#  ('way', 3),
#  ('year', 3),
#  ('good', 3),
#  ('woman', 2),
#  ('man', 2),
#  ('life', 2),
#  ('world', 2),
#  ('idea', 2),
#  ('sex', 1),
#  ('sexual', 1),
#  ('girl', 1),
#  ('lot', 1),
#  ('child', 1),
#  ('male', 1),
#  ('religion', 1),
#  ('human', 1),
#  ('religious', 1),
#  ('compassion', 1),
#  ('day', 1),
#  ('country', 1),
#  ('power', 1),
#  ('political', 1),
#  ('government', 1),
#  ('new', 1),
#  ('problem', 1)]

# %% [markdown]
# Additional stop words:
# * talk, sex, sexual, religion, religious, political, politics

# %%
# If all three tags have the top word, exclude it
add_stop_words = [word for word, count in Counter(words).most_common() if count > 2]
add_stop_words
# Out:
# ['people', 'thing', 'time', 'way', 'year', 'good']

# %%
with open('data/spacy_stop_words.pkl', 'rb') as f:
    stop_words = list(pickle.load(f))
    f.close()

# %%
def update_stop_words(list_to_update, add_stop_words):
    """Add custom stop words to stop word list"""
    stop_words = list_to_update
    for word in add_stop_words:
        stop_words.append(word)
    return stop_words

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Load clean dataframe
nouns_adj_df = pd.read_pickle('data/processed_transcript_df.pkl')

# Add new stop words
stop_words = update_stop_words(stop_words, add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(nouns_adj_df['transcript'])
dtm_df = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
dtm_df.index = nouns_adj_df.index

# Pickle it for later use
with open('data/cv_stop.pkl', 'wb') as f:
    pickle.dump(cv, f)
    f.close()
# Out:
# /Users/miguel/anaconda3/envs/metis/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# ## Word clouds

# %%
# Load clean df
nouns_adj_df = pd.read_pickle('data/processed_transcript_df.pkl')

# %%
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color='white', colormap='Dark2',
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

tags = ['sex', 'religions', 'politics']

# Create subplots for each comedian
for index, tags in enumerate(data.columns):
    wc.generate(nouns_adj_df.transcript[tag])
    
    plt.subplot(3, 1, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(tags[index])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-06d2977e46da> in <module>
#       7
#       8 # Create subplots for each comedian
# ----> 9 for index, tags in enumerate(data.columns):
#      10     wc.generate(nouns_adj_df.transcript[tag])
#      11
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## NMF / LDA
# Non-Negative Matrix Factorization (NMF)
#
# Find two non-negative matrices (W, H) whose product approximates the non-
# negative matrix X. This factorization can be used for example for
# dimensionality reduction, source separation or topic extraction.
#
# * LDA tends to work better on larger documents

# %%
no_topics = 10

nmf_model = NMF(n_components=no_topics)
doc_topic = nmf_model.fit_transform(doc_word)

# %%
component_ix = []
for i in range(1, no_topics+1):
    component_ix.append('component_' + str(i))
    
topic_word = pd.DataFrame(nmf_model.components_.round(3),
                          index=component_ix,
                          columns=vectorizer.get_feature_names())
topic_word

# %%
# Create df for topics
no_top_words = 10
topic_df = pd.DataFrame()
for ix, topic in enumerate(nmf_model.components_):
    col = 'topic_' + str(ix+1)
    topic_df[col] = pd.Series(vectorizer.get_feature_names()[i] for i in topic.argsort()[:-no_top_words - 1:-1])

topic_df

# %% [markdown]
# The H matrix shows us the documents we started with, and how each document is made up of the 2 resulting topics. In this case:
# - The first document seems to be about 'X'
# - The last document seems to be about 'Y'
# - Everything in between is a combination of the two

# %%
H = pd.DataFrame(doc_topic.round(3),
                 index=df.loc[:20, 'title'],
                 columns=component_ix)
H

# %% [markdown]
# # Clustering

# %% [markdown]
# # Visualizations
# Use umap for visualizations, clustering, and reducing dimensionality

# %% [markdown]
# – to scrape all the links look for the hrefs of the homepage
# – do cleaning of which ones are not for videos
# –

# %% [markdown]
# # spaCy attributes

# %% [markdown]
# * Text: The original word text.
# * Lemma: The base form of the word.
# * POS: The simple part-of-speech tag.
# * Tag: The detailed part-of-speech tag.
# * Dep: Syntactic dependency, i.e. the relation between tokens.
# * Shape: The word shape – capitalization, punctuation, digits.
# * is alpha: Is the token an alpha character?
# * is stop: Is the token part of a stop list, i.e. the most common words of the language?

# %%
# Print token attributes
for doc in docs:
    print('{:<25}{:<25}{:<10}{:<10}{:<15}{:<10}{:<10}{:<10}'.format(
    'Text', 'Lemma', 'POS', 'Tag', 'Dependency', 'Shape', 'Alpha', 'Stop'))
    for token in doc:
        # This is for formatting only
        print('{:<25}{:<25}{:<10}{:<10}{:<15}{:<10}{:<10}{:<10}'.format(
            token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop))
    print('\n')
# Out:
# Text                     Lemma                    POS       Tag       Dependency     Shape     Alpha     Stop
# When                     when                     ADV       WRB       advmod         Xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# was                      be                       AUX       VBD       ROOT           xxx       1         1
# a                        a                        DET       DT        det            x         1         1
# teen                     teen                     NOUN      NN        attr           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# had                      have                     AUX       VBD       relcl          xxx       1         1
# terrible                 terrible                 ADJ       JJ        amod           xxxx      1         0
# periods                  period                   NOUN      NNS       dobj           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# had                      have                     AUX       VBD       ROOT           xxx       1         1
# crippling                crippling                ADJ       JJ        amod           xxxx      1         0
# cramps                   cramp                    NOUN      NNS       dobj           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# leaked                   leak                     VERB      VBD       ROOT           xxxx      1         0
# blood                    blood                    NOUN      NN        dobj           xxxx      1         0
# onto                     onto                     ADP       IN        prep           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# clothes                  clothe                   NOUN      NNS       pobj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# onto                     onto                     ADP       IN        conj           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# bed                      bed                      NOUN      NN        compound       xxx       1         0
# sheets                   sheet                    NOUN      NNS       pobj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# had                      have                     AUX       VBD       ROOT           xxx       1         1
# period                   period                   NOUN      NN        compound       xxxx      1         0
# diarrhea                 diarrhea                 NOUN      NN        dobj           xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# had                      have                     AUX       VBD       ROOT           xxx       1         1
# to                       to                       PART      TO        aux            xx        1         1
# miss                     miss                     VERB      VB        xcomp          xxxx      1         0
# school                   school                   NOUN      NN        dobj           xxxx      1         0
# one                      one                      NUM       CD        quantmod       xxx       1         1
# to                       to                       PART      TO        quantmod       xx        1         1
# two                      two                      NUM       CD        nummod         xxx       1         1
# days                     day                      NOUN      NNS       npadvmod       xxxx      1         0
# a                        a                        DET       DT        det            x         1         1
# month                    month                    NOUN      NN        npadvmod       xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# remember                 remember                 VERB      VBP       ROOT           xxxx      1         0
# sitting                  sit                      VERB      VBG       xcomp          xxxx      1         0
# on                       on                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# couch                    couch                    NOUN      NN        pobj           xxxx      1         0
# with                     with                     ADP       IN        prep           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# heating                  heating                  NOUN      NN        compound       xxxx      1         0
# pads                     pad                      NOUN      NNS       nsubj          xxxx      1         0
# thinking                 think                    VERB      VBG       pcomp          xxxx      1         0
# What                     what                     PRON      WP        nsubj          Xxxx      1         1
# s                        s                        VERB      VBZ       ccomp          x         1         0
# up                       up                       ADP       RP        advmod         xx        1         1
# with                     with                     ADP       IN        prep           xxxx      1         1
# this                     this                     DET       DT        pobj           xxxx      1         1
# When                     when                     ADV       WRB       advmod         Xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# ate                      eat                      VERB      VBD       advcl          xxx       1         0
# food                     food                     NOUN      NN        dobj           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# did                      do                       AUX       VBD       aux            xxx       1         1
# nt                       not                      PART      RB        neg            xx        1         0
# leak                     leak                     VERB      VB        ccomp          xxxx      1         0
# saliva                   saliva                   NOUN      NN        dobj           xxxx      1         0
# from                     from                     ADP       IN        prep           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# salivary                 salivary                 ADJ       JJ        amod           xxxx      1         0
# glands                   gland                    NOUN      NNS       pobj           xxxx      1         0
# When                     when                     ADV       WRB       advmod         Xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# went                     go                       VERB      VBD       advcl          xxxx      1         0
# for                      for                      ADP       IN        prep           xxx       1         1
# a                        a                        DET       DT        det            x         1         1
# walk                     walk                     NOUN      NN        pobj           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# did                      do                       AUX       VBD       aux            xxx       1         1
# nt                       not                      PART      RB        neg            xx        1         0
# leak                     leak                     VERB      VB        ROOT           xxxx      1         0
# fluid                    fluid                    NOUN      NN        dobj           xxxx      1         0
# from                     from                     ADP       IN        prep           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# knees                    knee                     NOUN      NNS       nmod           xxxx      1         0
# joint                    joint                    ADJ       JJ        amod           xxxx      1         0
# fluid                    fluid                    NOUN      NN        pobj           xxxx      1         0
# Why                      why                      ADV       WRB       advmod         Xxx       1         1
# was                      be                       AUX       VBD       ROOT           xxx       1         1
# menstruation             menstruation             NOUN      NN        nsubj          xxxx      1         0
# so                       so                       ADV       RB        advmod         xx        1         1
# different                different                ADJ       JJ        acomp          xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# wanted                   want                     VERB      VBD       ROOT           xxxx      1         0
# answers                  answer                   NOUN      NNS       dobj           xxxx      1         0
# to                       to                       ADP       IN        prep           xx        1         1
# these                    these                    DET       DT        det            xxxx      1         1
# questions                question                 NOUN      NNS       pobj           xxxx      1         0
# but                      but                      CCONJ     CC        cc             xxx       1         1
# there                    there                    PRON      EX        expl           xxxx      1         1
# was                      be                       AUX       VBD       ROOT           xxx       1         1
# no                       no                       DET       DT        det            xx        1         1
# one                      one                      NOUN      NN        attr           xxx       1         1
# for                      for                      ADP       IN        mark           xxx       1         1
# me                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# to                       to                       PART      TO        aux            xx        1         1
# ask                      ask                      VERB      VB        advcl          xxx       1         0
# My                       -PRON-                   DET       PRP$      poss           Xx        1         1
# mother                   mother                   NOUN      NN        nsubj          xxxx      1         0
# knew                     know                     VERB      VBD       ccomp          xxxx      1         0
# nothing                  nothing                  PRON      NN        dobj           xxxx      1         1
# about                    about                    ADP       IN        prep           xxxx      1         1
# menstruation             menstruation             NOUN      NN        pobj           xxxx      1         0
# except                   except                   SCONJ     IN        prep           xxxx      1         1
# that                     that                     SCONJ     IN        mark           xxxx      1         1
# it                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# was                      be                       AUX       VBD       pcomp          xxx       1         1
# dirty                    dirty                    ADJ       JJ        acomp          xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# shameful                 shameful                 ADJ       JJ        conj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# should                   should                   VERB      MD        aux            xxxx      1         1
# nt                       not                      PART      RB        neg            xx        1         0
# talk                     talk                     VERB      VB        conj           xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# it                       -PRON-                   PRON      PRP       pobj           xx        1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# asked                    ask                      VERB      VBD       ROOT           xxxx      1         0
# girlfriends              girlfriend               NOUN      NNS       dobj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# everybody                everybody                PRON      NN        nsubj          xxxx      1         0
# spoke                    speak                    VERB      VBD       conj           xxxx      1         0
# in                       in                       ADP       IN        prep           xx        1         1
# euphemisms               euphemism                NOUN      NNS       pobj           xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# finally                  finally                  ADV       RB        advmod         xxxx      1         0
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# got                      get                      VERB      VBD       ROOT           xxx       1         0
# the                      the                      DET       DT        det            xxx       1         1
# courage                  courage                  NOUN      NN        dobj           xxxx      1         0
# to                       to                       PART      TO        aux            xx        1         1
# go                       go                       VERB      VB        acl            xx        1         1
# to                       to                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# doctor                   doctor                   NOUN      NN        pobj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# talk                     talk                     VERB      VB        conj           xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# heavy                    heavy                    ADJ       JJ        amod           xxxx      1         0
# periods                  period                   NOUN      NNS       pobj           xxxx      1         0
# I                        -PRON-                   PRON      PRP       nsubjpass      X         1         1
# was                      be                       AUX       VBD       auxpass        xxx       1         1
# told                     tell                     VERB      VBN       relcl          xxxx      1         0
# to                       to                       PART      TO        aux            xx        1         1
# eat                      eat                      VERB      VB        xcomp          xxx       1         0
# liver                    liver                    NOUN      NN        dobj           xxxx      1         0
#                                                   SPACE     _SP                                0         0
# And                      and                      CCONJ     CC        ROOT           Xxx       1         1
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# went                     go                       VERB      VBD       intj           xxxx      1         0
# to                       to                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# drug                     drug                     NOUN      NN        compound       xxxx      1         0
# store                    store                    NOUN      NN        pobj           xxxx      1         0
# to                       to                       PART      TO        aux            xx        1         1
# buy                      buy                      VERB      VB        advcl          xxx       1         0
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# menstrual                menstrual                ADJ       JJ        amod           xxxx      1         0
# products                 product                  NOUN      NNS       dobj           xxxx      1         0
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
#                                                   SPACE     _SP                                0         0
# of                       of                       ADP       IN        prep           xx        1         1
# super                    super                    PROPN     NNP       amod           xxxx      1         0
# maxi                     maxi                     PROPN     NNP       pobj           xxxx      1         0
# pads                     pad                      VERB      VBZ       ROOT           xxxx      1         0
# back                     back                     ADV       RB        advmod         xxxx      1         1
# in                       in                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# day                      day                      NOUN      NN        pobj           xxx       1         0
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# they                     -PRON-                   PRON      PRP       nsubj          xxxx      1         1
# were                     be                       AUX       VBD       relcl          xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# size                     size                     NOUN      NN        attr           xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# a                        a                        DET       DT        det            x         1         1
# tissue                   tissue                   NOUN      NN        compound       xxxx      1         0
# box                      box                      NOUN      NN        pobj           xxx       1         0
# each                     each                     DET       DT        det            xxxx      1         1
# pad                      pad                      NOUN      NN        npadvmod       xxx       1         0
# —                        —                        PUNCT     :         punct          —         0         0
#                                                   SPACE     _SP                                0         0
# You                      -PRON-                   PRON      PRP       nsubj          Xxx       1         1
# know                     know                     VERB      VBP       ROOT           xxxx      1         0
# what                     what                     PRON      WP        dobj           xxxx      1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# m                        be                       VERB      VBP       nsubj          x         1         0
# talking                  talk                     VERB      VBG       ROOT           xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# You                      -PRON-                   PRON      PRP       pobj           Xxx       1         1
# have                     have                     AUX       VBP       ROOT           xxxx      1         1
# no                       no                       DET       DT        det            xx        1         1
# idea                     idea                     NOUN      NN        dobj           xxxx      1         0
# how                      how                      ADV       WRB       advmod         xxx       1         1
# far                      far                      ADV       RB        advmod         xxx       1         0
# absorbent                absorbent                ADJ       JJ        amod           xxxx      1         0
# technology               technology               NOUN      NN        nsubj          xxxx      1         0
# has                      have                     AUX       VBZ       aux            xxx       1         1
# come                     come                     VERB      VBN       relcl          xxxx      1         0
#                                                   SPACE     _SP                                0         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# used                     use                      VERB      VBD       ROOT           xxxx      1         1
# to                       to                       PART      TO        aux            xx        1         1
# have                     have                     AUX       VB        xcomp          xxxx      1         1
# to                       to                       PART      TO        aux            xx        1         1
# buy                      buy                      VERB      VB        xcomp          xxx       1         0
# my                       -PRON-                   DET       PRP$      poss           xx        1         1
# menstrual                menstrual                ADJ       JJ        amod           xxxx      1         0
# products                 product                  NOUN      NNS       dobj           xxxx      1         0
# in                       in                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# feminine                 feminine                 ADJ       JJ        amod           xxxx      1         0
# hygiene                  hygiene                  NOUN      NN        compound       xxxx      1         0
# aisle                    aisle                    NOUN      NN        pobj           xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# remember                 remember                 VERB      VBP       ROOT           xxxx      1         0
# standing                 stand                    VERB      VBG       xcomp          xxxx      1         0
# there                    there                    ADV       RB        advmod         xxxx      1         1
# thinking                 think                    VERB      VBG       advcl          xxxx      1         0
# Well                     well                     INTJ      UH        intj           Xxxx      1         1
# why                      why                      ADV       WRB       advmod         xxx       1         1
# do                       do                       AUX       VBP       aux            xx        1         1
# nt                       not                      PART      RB        intj           xx        1         0
# I                        -PRON-                   PRON      PRP       nsubj          X         1         1
# buy                      buy                      VERB      VBP       ROOT           xxx       1         0
# toilet                   toilet                   NOUN      NN        compound       xxxx      1         0
# paper                    paper                    NOUN      NN        dobj           xxxx      1         0
# in                       in                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# anal                     anal                     ADJ       JJ        amod           xxxx      1         0
# hygiene                  hygiene                  NOUN      NN        compound       xxxx      1         0
# aisle                    aisle                    NOUN      NN        pobj           xxxx      1         0
#                                                   SPACE     _SP                                0         0
# Like                     like                     INTJ      UH        intj           Xxxx      1         0
# what                     what                     PRON      WP        nsubj          xxxx      1         1
# s                        s                        VERB      VBZ       ROOT           x         1         0
# up                       up                       ADP       RP        prt            xx        1         1
# with                     with                     ADP       IN        prep           xxxx      1         1
# that                     that                     DET       DT        pobj           xxxx      1         1
# Why                      why                      ADV       WRB       advmod         Xxx       1         1
# ca                       can                      VERB      MD        aux            xx        1         1
# nt                       not                      PART      RB        neg            xx        1         0
# we                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# talk                     talk                     VERB      VB        ROOT           xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# periods                  period                   NOUN      NNS       pobj           xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# its                      -PRON-                   DET       PRP$      conj           xxx       1         1
# not                      not                      PART      RB        neg            xxx       1         1
# about                    about                    ADP       IN        prep           xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# blood                    blood                    NOUN      NN        pobj           xxxx      1         0
# as                       as                       SCONJ     IN        prep           xx        1         1
# Freud                    Freud                    PROPN     NNP       pobj           Xxxxx     1         0
# would                    would                    VERB      MD        aux            xxxx      1         1
# have                     have                     AUX       VB        aux            xxxx      1         1
# you                      -PRON-                   PRON      PRP       nsubj          xxx       1         1
# say                      say                      VERB      VB        ROOT           xxx       1         1
# because                  because                  SCONJ     IN        mark           xxxx      1         1
# if                       if                       SCONJ     IN        mark           xx        1         1
# it                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# were                     be                       AUX       VBD       advcl          xxxx      1         1
# there                    there                    PRON      EX        expl           xxxx      1         1
# would                    would                    VERB      MD        aux            xxxx      1         1
# be                       be                       AUX       VB        advcl          xx        1         1
# an                       an                       DET       DT        det            xx        1         1
# ear                      ear                      NOUN      NN        compound       xxx       1         0
# nose                     nose                     NOUN      NN        attr           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# throat                   throat                   NOUN      NN        conj           xxxx      1         0
# surgeon                  surgeon                  NOUN      NN        conj           xxxx      1         0
# up                       up                       ADV       RB        advmod         xx        1         1
# here                     here                     ADV       RB        advmod         xxxx      1         1
# right                    right                    ADV       RB        advmod         xxxx      1         0
# now                      now                      ADV       RB        advmod         xxx       1         1
# talking                  talk                     VERB      VBG       advcl          xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# taboos                   taboo                    NOUN      NNS       pobj           xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# nose                     nose                     NOUN      NN        pobj           xxxx      1         0
# bleeds                   bleed                    NOUN      NNS       ROOT           xxxx      1         0
# right                    right                    ADV       RB        acomp          xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# its                      -PRON-                   DET       PRP$      poss           xxx       1         1
# not                      not                      PART      RB        neg            xxx       1         1
# even                     even                     ADV       RB        advmod         xxxx      1         1
# about                    about                    ADP       IN        prep           xxxx      1         1
# periods                  period                   NOUN      NNS       pobj           xxxx      1         0
# because                  because                  SCONJ     IN        mark           xxxx      1         1
# otherwise                otherwise                ADV       RB        advmod         xxxx      1         1
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# we                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# got                      get                      VERB      VBD       auxpass        xxx       1         0
# rid                      rid                      VERB      VBN       advcl          xxx       1         0
# of                       of                       ADP       IN        prep           xx        1         1
# our                      -PRON-                   DET       PRP$      poss           xxx       1         1
# toxic                    toxic                    ADJ       JJ        amod           xxxx      1         0
# shameful                 shameful                 ADJ       JJ        amod           xxxx      1         0
# periods                  period                   NOUN      NNS       pobj           xxxx      1         0
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# we                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# became                   become                   VERB      VBD       advcl          xxxx      1         1
# menopausal               menopausal               ADJ       JJ        acomp          xxxx      1         0
# we                       -PRON-                   PRON      PRP       compound       xx        1         1
# d                        would                    VERB      MD        nsubjpass      x         1         0
# be                       be                       AUX       VB        auxpass        xx        1         1
# elevated                 elevate                  VERB      VBN       ROOT           xxxx      1         0
# to                       to                       ADP       IN        prep           xx        1         1
# a                        a                        DET       DT        det            x         1         1
# higher                   high                     ADJ       JJR       amod           xxxx      1         0
# social                   social                   ADJ       JJ        amod           xxxx      1         0
# status                   status                   NOUN      NN        pobj           xxxx      1         0
#                                                   SPACE     _SP                                0         0
# Its                      -PRON-                   DET       PRP$      poss           Xxx       1         1
# just                     just                     ADV       RB        advmod         xxxx      1         1
# a                        a                        DET       DT        det            x         1         1
# patriarchal              patriarchal              ADJ       JJ        amod           xxxx      1         0
# society                  society                  NOUN      NN        nsubjpass      xxxx      1         0
# is                       be                       AUX       VBZ       auxpass        xx        1         1
# invested                 invest                   VERB      VBN       ROOT           xxxx      1         0
# in                       in                       ADP       IN        prep           xx        1         1
# oppressing               oppress                  VERB      VBG       pcomp          xxxx      1         0
# women                    woman                    NOUN      NNS       dobj           xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# at                       at                       ADP       IN        prep           xx        1         1
# different                different                ADJ       JJ        amod           xxxx      1         0
# points                   point                    NOUN      NNS       pobj           xxxx      1         0
# in                       in                       ADP       IN        prep           xx        1         1
# our                      -PRON-                   DET       PRP$      poss           xxx       1         1
# lives                    life                     NOUN      NNS       pobj           xxxx      1         0
# different                different                ADJ       JJ        amod           xxxx      1         0
# things                   thing                    NOUN      NNS       nsubjpass      xxxx      1         0
# are                      be                       AUX       VBP       auxpass        xxx       1         1
# used                     use                      VERB      VBN       conj           xxxx      1         1
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# menstruation             menstruation             NOUN      NN        nsubjpass      xxxx      1         0
# is                       be                       AUX       VBZ       auxpass        xx        1         1
# used                     use                      VERB      VBN       conj           xxxx      1         1
# during                   during                   ADP       IN        prep           xxxx      1         1
# what                     what                     PRON      WP        dobj           xxxx      1         1
# we                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# in                       in                       ADP       IN        prep           xx        1         1
# medicine                 medicine                 NOUN      NN        pobj           xxxx      1         0
# call                     call                     VERB      VBP       pcomp          xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# reproductive             reproductive             ADJ       JJ        amod           xxxx      1         0
# years                    year                     NOUN      NNS       oprd           xxxx      1         0
# Its                      -PRON-                   DET       PRP$      nsubj          Xxx       1         1
# been                     be                       AUX       VBN       ccomp          xxxx      1         1
# around                   around                   ADV       RB        advmod         xxxx      1         1
# since                    since                    SCONJ     IN        prep           xxxx      1         1
# pretty                   pretty                   ADV       RB        advmod         xxxx      1         0
# much                     much                     ADV       RB        pobj           xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# beginning                beginning                NOUN      NN        pobj           xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# time                     time                     NOUN      NN        pobj           xxxx      1         0
# many                     many                     ADJ       JJ        amod           xxxx      1         1
# cultures                 culture                  NOUN      NNS       nsubj          xxxx      1         0
# thought                  think                    VERB      VBD       relcl          xxxx      1         0
# that                     that                     SCONJ     IN        mark           xxxx      1         1
# women                    woman                    NOUN      NNS       nsubj          xxxx      1         0
# could                    could                    VERB      MD        aux            xxxx      1         1
# spoil                    spoil                    VERB      VB        ccomp          xxxx      1         0
# crops                    crop                     NOUN      NNS       dobj           xxxx      1         0
# or                       or                       CCONJ     CC        cc             xx        1         1
# milk                     milk                     NOUN      NN        conj           xxxx      1         0
# or                       or                       CCONJ     CC        cc             xx        1         1
# wilt                     wilt                     NOUN      NN        conj           xxxx      1         0
# flowers                  flower                   NOUN      NNS       dobj           xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# then                     then                     ADV       RB        advmod         xxxx      1         1
# when                     when                     ADV       WRB       advmod         xxxx      1         1
# religion                 religion                 NOUN      NN        nsubj          xxxx      1         0
# came                     come                     VERB      VBD       advcl          xxxx      1         0
# along                    along                    ADP       IN        prep           xxxx      1         1
# purity                   purity                   NOUN      NN        compound       xxxx      1         0
# myths                    myth                     NOUN      NNS       pobj           xxxx      1         0
# only                     only                     ADV       RB        advmod         xxxx      1         1
# made                     make                     VERB      VBD       ROOT           xxxx      1         1
# that                     that                     SCONJ     IN        nsubj          xxxx      1         1
# worse                    bad                      ADJ       JJR       ccomp          xxxx      1         0
# And                      and                      CCONJ     CC        cc             Xxx       1         1
# medicine                 medicine                 NOUN      NN        nsubj          xxxx      1         0
# was                      be                       AUX       VBD       ROOT           xxx       1         1
# nt                       not                      PART      RB        neg            xx        1         0
# any                      any                      DET       DT        det            xxx       1         1
# help                     help                     NOUN      NN        attr           xxxx      1         0
# In                       in                       ADP       IN        prep           Xx        1         1
# the                      the                      DET       DT        pobj           xxx       1         1
#                                                   SPACE     _SP                                0         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
#                                                   SPACE     _SP                                0         0
# there                    there                    PRON      EX        expl           xxxx      1         1
# was                      be                       AUX       VBD       ROOT           xxx       1         1
# the                      the                      DET       DT        det            xxx       1         1
# ...
# that                     that                     ADV       RB        advmod         xxxx      1         1
# confused                 confused                 ADJ       JJ        ccomp          xxxx      1         0
# about                    about                    ADP       IN        prep           xxxx      1         1
# womens                   womens                   PROPN     NNP       compound       xxxx      1         0
# bodies                   body                     NOUN      NNS       pobj           xxxx      1         0
# why                      why                      ADV       WRB       advmod         xxx       1         1
# did                      do                       AUX       VBD       aux            xxx       1         1
# nt                       not                      PART      RB        neg            xx        1         0
# they                     -PRON-                   PRON      PRP       nsubj          xxxx      1         1
# just                     just                     ADV       RB        advmod         xxxx      1         1
# ask                      ask                      VERB      VBP       relcl          xxx       1         0
# women                    woman                    NOUN      NNS       dobj           xxxx      1         0
# for                      for                      ADP       IN        prep           xxx       1         1
# a                        a                        DET       DT        det            x         1         1
# little                   little                   ADJ       JJ        amod           xxxx      1         0
# help                     help                     NOUN      NN        pobj           xxxx      1         0
# But                      but                      CCONJ     CC        cc             Xxx       1         1
# you                      -PRON-                   PRON      PRP       nsubj          xxx       1         1
# must                     must                     VERB      MD        aux            xxxx      1         1
# be                       be                       AUX       VB        aux            xx        1         1
# thinking                 think                    VERB      VBG       ROOT           xxxx      1         0
# All                      all                      DET       PDT       dobj           Xxx       1         1
# that                     that                     DET       WDT       nsubj          xxxx      1         1
# was                      be                       AUX       VBD       relcl          xxx       1         1
# history                  history                  NOUN      NN        attr           xxxx      1         0
# Its                      -PRON-                   DET       PRP$      poss           Xxx       1         1
# a                        a                        DET       DT        det            x         1         1
# different                different                ADJ       JJ        amod           xxxx      1         0
# world                    world                    NOUN      NN        ROOT           xxxx      1         0
# now                      now                      ADV       RB        advmod         xxx       1         1
# Women                    woman                    NOUN      NNS       nsubj          Xxxxx     1         0
# have                     have                     AUX       VBP       ROOT           xxxx      1         1
# everything               everything               PRON      NN        nsubj          xxxx      1         1
# They                     -PRON-                   PRON      PRP       nsubj          Xxxx      1         1
# have                     have                     AUX       VBP       relcl          xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# birth                    birth                    NOUN      NN        compound       xxxx      1         0
# control                  control                  NOUN      NN        compound       xxxx      1         0
# pill                     pill                     NOUN      NN        dobj           xxxx      1         0
# they                     -PRON-                   PRON      PRP       nsubj          xxxx      1         1
# have                     have                     AUX       VBP       relcl          xxxx      1         1
# sexting                  sexte                    VERB      VBG       xcomp          xxxx      1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# Tinder                   Tinder                   PROPN     NNP       conj           Xxxxx     1         0
# and                      and                      CCONJ     CC        cc             xxx       1         1
# vajazzling               vajazzle                 VERB      VBG       conj           xxxx      1         0
#                                                   SPACE     _SP                                0         0
# Things                   thing                    NOUN      NNS       dobj           Xxxxx     1         0
# must                     must                     VERB      MD        aux            xxxx      1         1
# be                       be                       AUX       VB        ccomp          xx        1         1
# better                   well                     ADJ       JJR       acomp          xxxx      1         0
# now                      now                      ADV       RB        advmod         xxx       1         1
# But                      but                      CCONJ     CC        cc             Xxx       1         1
# medical                  medical                  ADJ       JJ        amod           xxxx      1         0
# ignorance                ignorance                NOUN      NN        nsubj          xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# female                   female                   ADJ       JJ        amod           xxxx      1         0
# body                     body                     NOUN      NN        pobj           xxxx      1         0
# continues                continue                 VERB      VBZ       ROOT           xxxx      1         0
# How                      how                      ADV       WRB       advmod         Xxx       1         1
# many                     many                     ADJ       JJ        nsubj          xxxx      1         1
# of                       of                       ADP       IN        prep           xx        1         1
# you                      -PRON-                   PRON      PRP       pobj           xxx       1         1
# recognize                recognize                VERB      VBP       ccomp          xxxx      1         0
# this                     this                     DET       DT        det            xxxx      1         1
# Its                      -PRON-                   DET       PRP$      poss           Xxx       1         1
# the                      the                      DET       DT        det            xxx       1         1
# full                     full                     ADJ       JJ        amod           xxxx      1         1
# structure                structure                NOUN      NN        dobj           xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# clitoris                 clitoris                 NOUN      NN        pobj           xxxx      1         0
# We                       -PRON-                   PRON      PRP       nsubj          Xx        1         1
# think                    think                    VERB      VBP       ROOT           xxxx      1         0
# of                       of                       ADP       IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# clitoris                 clitoris                 NOUN      NN        pobj           xxxx      1         0
# as                       as                       SCONJ     IN        prep           xx        1         1
# this                     this                     DET       DT        det            xxxx      1         1
# little                   little                   ADJ       JJ        advmod         xxxx      1         0
# peasized                 peasize                  VERB      VBD       amod           xxxx      1         0
# nub                      nub                      ADV       RB        pobj           xxx       1         0
# but                      but                      CCONJ     CC        cc             xxx       1         1
# actually                 actually                 ADV       RB        advmod         xxxx      1         0
# it                       -PRON-                   PRON      PRP       nsubj          xx        1         1
# extends                  extend                   VERB      VBZ       ROOT           xxxx      1         0
# deep                     deep                     ADV       RB        advmod         xxxx      1         0
# into                     into                     ADP       IN        prep           xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# body                     body                     NOUN      NN        pobj           xxxx      1         0
# Most                     Most                     ADJ       JJS       nsubj          Xxxx      1         1
# of                       of                       ADP       IN        prep           xx        1         1
# it                       -PRON-                   PRON      PRP       pobj           xx        1         1
# lies                     lie                      VERB      VBZ       relcl          xxxx      1         0
# under                    under                    ADP       IN        prep           xxxx      1         1
# the                      the                      DET       DT        det            xxx       1         1
# skin                     skin                     NOUN      NN        pobj           xxxx      1         0
# It                       -PRON-                   PRON      PRP       nsubj          Xx        1         1
# contains                 contain                  VERB      VBZ       ROOT           xxxx      1         0
# almost                   almost                   ADV       RB        advmod         xxxx      1         1
# as                       as                       ADV       RB        advmod         xx        1         1
# much                     much                     ADJ       JJ        amod           xxxx      1         1
# erectile                 erectile                 ADJ       JJ        amod           xxxx      1         0
# tissue                   tissue                   NOUN      NN        dobj           xxxx      1         0
# as                       as                       SCONJ     IN        prep           xx        1         1
# the                      the                      DET       DT        det            xxx       1         1
# penis                    penis                    NOUN      NN        pobj           xxxx      1         0
# Its                      -PRON-                   DET       PRP$      poss           Xxx       1         1
# beautiful                beautiful                ADJ       JJ        nsubj          xxxx      1         0
# is                       be                       AUX       VBZ       ROOT           xx        1         1
# nt                       not                      PART      RB        neg            xx        1         0
# it                       -PRON-                   PRON      PRP       attr           xx        1         1
# It                       -PRON-                   PRON      PRP       nsubj          Xx        1         1
# looks                    look                     VERB      VBZ       ROOT           xxxx      1         0
# a                        a                        DET       DT        det            x         1         1
# little                   little                   ADJ       JJ        npadvmod       xxxx      1         0
# like                     like                     SCONJ     IN        prep           xxxx      1         0
# a                        a                        DET       DT        det            x         1         1
# swan                     swan                     NOUN      NN        pobj           xxxx      1         0
#                                                   SPACE     _SP                                0         0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-5521bc043eaa> in <module>
#       7         print('{:<25}{:<25}{:<10}{:<10}{:<15}{:<10}{:<10}{:<10}'.format(
#       8             token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
# ----> 9             token.shape_, token.is_alpha, token.is_stop))
#      10     print('\n')
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Iterate through each doc in the corpus
for ix, doc in enumerate(docs):
    # Print each doc (transcript)
    print(f'\nDoc: {ix}\n{doc}\n')
    
    # Iterate through the predicted entities
    # Print the entity text and its label
    print(
        tabulate([(ent.text, ent.label_) for ent in doc.ents],
                 headers=['Entity', 'Label'],
                 tablefmt='github'))
    
    # Extract labels from entities and store
    labels = [ent.label_ for ent in doc.ents]
    
    # Iterate through the predicted labels
    # Print the label and its count
    print('\n')
    print(
        tabulate([(count, label) for label, count in Counter(labels).items()],
                 headers=['Count', 'Label'],
                 tablefmt='github'))

# %% [markdown]
# # Stanford NLP + SpaCy

# %%
import stanfordnlp
from spacy_stanfordnlp import StanfordNLPLanguage

snlp = stanfordnlp.Pipeline(lang="en")
nlp = StanfordNLPLanguage(snlp)

doc = nlp("Barack Obama was born in Hawaii. He was elected president in 2008.")

# %%
print('{:<25}{:<25}{:<10}{:<10}{:<15}{:<10}{:<10}{:<10}'.format(
'Text', 'Lemma', 'POS', 'Tag', 'Dependency', 'Shape', 'Alpha', 'Stop'), '\n')

for token in doc:
    # This is for formatting only
    print('{:<25}{:<25}{:<10}{:<10}{:<15}{:<10}{:<10}{:<10}'.format(
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop))
print('\n')

# %%
from spacy import displacy
displacy.render(doc)
